# %% [markdown]
# ![Banner](https://github.com/Data-Dunkers/lessons/blob/main/images/top-banner.jpg?raw=true)

# %% [markdown]
# # Shot Chart
#
# Basketball shot charts show where players take their shots on the court and how successful they were. This visualization helps you understand players' shooting patterns and effectiveness.
#
# We'll start by importing and displaying the shot data for the [Indiana Pacers](https://en.wikipedia.org/wiki/Indiana_Pacers) from the 2024-2025 season.

# %%
import pandas as pd
shots = pd.read_csv('https://raw.githubusercontent.com/Data-Dunkers/data/refs/heads/main/NBA/pacers-shots-2024-2025.csv')
shots

# %% [markdown]
# ## 1. Visualizing Shot Locations
#
# Now that we have the data, we can create a visualization of the court locations (`LOC_X` and `LOC_Y`) of all those shots.

# %%
import plotly.express as px
px.scatter(shots, x='LOC_X', y='LOC_Y', height=1000, width=800, color='PLAYER_NAME')

# %% [markdown]
# ## 2. Adding Interaction
#
# We can also add some more data to the visualization from other columns in the dataframe, like the `ACTION_TYPE`.

# %%
px.scatter(shots, x='LOC_X', y='LOC_Y', height=1100, width=900, color='ACTION_TYPE', hover_data=['PLAYER_NAME', 'SHOT_MADE_FLAG', 'SHOT_DISTANCE', 'PERIOD'])

# %% [markdown]
# You can hover over points to see player names and other information. Click or double-click on the shot types in the legend to filter the data.
#
# ## Reflection Questions
#
# 1. What do you notice about the shooting patterns?
# 2. Are there areas on the court where players tend to shoot more or less?
# 3. How might this information be useful for coaches and players?
#
# ---
#
# ### Online Access
# You can run this notebook online using the following links:
#
# *   [**Google Colab**](https://colab.research.google.com/github/Data-Dunkers/student/blob/main/activities/shot-charts.ipynb)
# *   [**Callysto Hub**](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FData-Dunkers%2Fstudent&branch=main&subPath=activities/shot-charts.ipynb&depth=1)
