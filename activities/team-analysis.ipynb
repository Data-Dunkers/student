# %% [markdown]
# ![Banner](https://github.com/Data-Dunkers/lessons/blob/main/images/top-banner.jpg?raw=true)

# %% [markdown]
# # Lesson: Team Analysis Coding Challenge
#
# In this activity, we will use Python to compare the performance of multiple NBA teams. First we will import the data from the 2025-2026 season.

# %%
import pandas as pd
import plotly.express as px
df = pd.read_csv('https://raw.githubusercontent.com/Data-Dunkers/data/refs/heads/main/NBA/team/nba_team_stats_2025-2026.csv')
df

# %% [markdown]
# ## Visualizing with Plotly
#
# We will use `plotly.express` to create a grouped bar chart.

# %%
metrics = ['PTS', 'REB', 'AST', 'STL', 'BLK']  # the metrics we want to compare
px.bar(df, x='Team', y=metrics, barmode='group', title='NBA Team Comparison (2025-2026)')

# %% [markdown]
# If we'd like to include just a selection of teams, we can first list all of the teams.

# %%
df['teams']

# %% [markdown]
# Then we can filter the dataframe for just the teams we would like to show.

# %%
teams = ['Indiana Pacers', 'Toronto Raptors', 'Boston Celtics']
filtered_df = df[df['Team'].isin(teams)]
metrics = ['PTS', 'REB', 'AST', 'STL', 'BLK']
px.bar(filtered_df, x='Team', y=metrics, barmode='group', title='Selected NBA Team Comparison (2025-2026)')

# %% [markdown]
# ## Questions
#
# 1. Why would we use a grouped bar chart when comparing multiple teams and metrics like points, rebounds, assists, steals, and blocks?
# 2. Which NBA team in the dataset appears to be the strongest offensive team based on points scored, and how can you tell from the chart?
# 3. What is the purpose of using the Team column and the isin() method in the notebook?
#
# ---
#
# ### Online Access
# You can run this notebook online using the following links:
#
# * [JupyterLite](https://datadunkers.ca/jupyterlite/notebooks/index.html?path=activities%2Fteam-analysis.ipynb)
# * [Google Colab](https://colab.research.google.com/github/Data-Dunkers/student/blob/main/activities/team-analysis.ipynb)
# * [Callysto Hub](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FData-Dunkers%2Fstudent&branch=main&subPath=activities/team-analysis.ipynb&depth=1)
